# %% [markdown]
# <font size = "3">
#
# **(Q1)** Consider the following algorithm:
#
# <div style="text-align: center;">
#   <img src="files/gauss_algorithm.png" alt="Centered image" width = "550">
#   <br>
#   <br>
#   <figcaption>
#   <font size = "2"> Michael T. Heath (Scientific Computing: An Introductory Survey)</figcaption>
# </div>
#
# <br>
#
# <font size = "3">
#
# This computes the LU factorization $A = LU$ using Gaussian elimination *in-place*. That is, it overwrites the entries of $A$ with its factors $L$ (unit lower-triangular) and $U$ (upper-triangular).
#
# Write a function that implements this algorithm with **no inner loops**. That is, all operations inside the "for k" loop should be vectorized.
#
# **Warning:** The algorithm above starts counting at "1", not "0" like in Python

# %% [markdown]
# <font size = "3">
#
# **(Q2)** Equivalent variants of LU factorization with Gaussian elimination can be implemented with different access patterns, which means the order of the loops can be permuted:
#
# <div style="text-align: center;">
#   <img src="files/generic_gauss.png" alt="Centered image" width = "550">
#   <br>
#   <br>
#   <figcaption>
#   <font size = "2"> Michael T. Heath (Scientific Computing: An Introductory Survey)</figcaption>
# </div>
#
# <br>
#
# <font size = "3">
#
# - Write functions that implement Gaussian elimination with two other possible loop orderings, besides the one in **(Q1)**
#
# - Then implement these two functions using vectorized operations to the extent that is possible.

# %% [markdown]
# <font size = "3">
#
# **(Q3)** Test your 3 vectorized implementations on randomly generated square matrices of various sizes. Generate a plot showing the runtime for each variant as a function of the matrix dimension.

# %% [markdown]
# <font size = "3">
#
# **(Q4)** Recreate the figure from "lecture_26_a.ipynb" which shows the error in computing $\dfrac{\textrm{d}}{\textrm{d}x} \sin(x)\bigg\rvert_{x=1}$ using the finite difference formula
#
# $$f'(x) \approx \frac{f(x + h) - f(x)}{h} =: \hat{y}$$
#
# (where $f(x) = \sin(x)$ and $x = 1$) for different values of $h > 0$. Using logarithmic scaling on both axes, just like the original figure.

# %% [markdown]
# <font size = "3">
#
# **(Q5)** Write a program to solve the quadratic equation $ax^2 + bx + c = 0$ using the standard quadratic formula
#
# $$ x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$
#
# or the alternative formula
#
# $$x = \frac{2c}{-b \mp \sqrt{b^2 - 4ac}}$$
#
# Your function should accept the coefficients $a, b, c$ of a quadratic polynomial, and return the two roots as output. The function should detect when the roots are not real, but you're not required to use complex arithmetic explicitly (for example, you could decide to return the real and imaginary parts of the complex conjugate roots in this case).
#
# You should guard against unnecessary overflow (going beyond the range of largest representable numbers), unnecessary underflow (going below the range of smallest positive representable numbers), and unnecessary cancellation (subtraction of two numbers with comparable magnitude). When should you use each of the two formulas?
#
# Try to make your program robust when given unusual inputs such as $a = 0$ or $c = 0$. Any roots that is within the range of representable numbers on the computer should be computed accurately, even if the other is out of range.
#
# Test your function using the following inputs:
#
#
# | $a$ | $b$ | $c$ |
# |----------|----------|----------|
# | 6   | 5   | -4   |
# | $6\times 10^{154}$   | $5\times 10^{154}$   | $-4\times 10^{154}$   |
# | 0   | 1   | 1   |
# | 1   | -10^5   | 1  |
# | 1   | -4   | 3.999999   |
# | $10^{-155}$   | $-10^{155}$   | $10^{155}$ |
